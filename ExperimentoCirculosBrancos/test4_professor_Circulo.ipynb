# %% [markdown]
# <a href="https://colab.research.google.com/github/Gus-1003/TADS_Projeto_PalmaS/blob/main/ExperimentoCirculosBrancos/test4_professor_Circulo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

from google.colab import drive

from google.colab.patches import cv2_imshow

# %%
drive.mount('/content/drive')
bgrImg = cv2.imread("/content/drive/MyDrive/Colab Notebooks/fig_control_1.jpg")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
grayImg = cv2.cvtColor(bgrImg, cv2.COLOR_BGR2GRAY)
avgImg = cv2.medianBlur(grayImg, 1)
# plt.imshow(bgrImg) # branco fica azulado e o marrom azul mais escuro
cv2_imshow(avgImg)
# Out:
# <PIL.Image.Image image mode=L size=800x800 at 0x7FCDC1ABAC10>

# %%
# plt.subplot(3,3,1)
# plt.imshow(grayImg)
# plt.subplot(3,3,2)
# plt.hist(grayImg.ravel(),256,[0,256])
# plt.subplot(3,3,3)
# plt.imshow(avgImg)
# plt.show()
